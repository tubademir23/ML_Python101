# %%
type('selam')
# Out:
# str

# %%
ad="tuba"
"selam "+ ad + " nasil"
# Out:
# 'selam tuba nasil'

# %%
"python"*2
# Out:
# 'pythonpython'

# %%
first=1
second=2
first,second=second, first
first**=6
print(first/9)
print(first//9)#kalansız bölme
# Out:
# 7.111111111111111
# 7

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
print(first)
del first
print(first)
# Out:
# 64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-131-d56c8f4fc1d5> in <module>
#       1 print(first)
#       2 del first
# ----> 3 print(first)
#
# NameError: name 'first' is not defined

# %%
matrix=[[0,1,2],[3,4,5],[6,7,8]]
for i in matrix:
    list=[]
    for j in matrix:
        list.extend(j)
    print(list)
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
sozluk={}
sozluk["selam"]="merhaba"
sozluk["aney"]="anne"
print(sozluk)
sozlukkey=sozluk.keys
sozlukvalue=sozluk.values
sozluk.setdefault('hello','slm')
sozluk.setdefault('yogurt','yogurt')
print(sozluk)

sozlukeng={}
sozlukeng["yogurt"]="yogurt"
# Out:
# {'selam': 'merhaba', 'aney': 'anne'}
# {'selam': 'merhaba', 'aney': 'anne', 'hello': 'slm', 'yogurt': 'yogurt'}

# %%
kume1=set(sozluk)
kume2=set(sozlukeng)
print(kume1)
print(kume2)
print("Kesişim: ", kume1.intersection(kume2))
print("Birleşim: ", kume1.union(kume2))
# Out:
# {'yogurt', 'selam', 'hello', 'aney'}
# {'yogurt'}
# Kesişim:  {'yogurt'}
# Birleşim:  {'selam', 'hello', 'yogurt', 'aney'}

# %%
liste1= sozluk

# %%
listem=sorted(sozluk)
print(*enumerate(listem))
# Out:
# (0, 'aney') (1, 'hello') (2, 'selam') (3, 'yogurt')

# %%
for no, value in enumerate(listem,0):
    print('N: {0} V: {1}'.format(no,value ))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c91c1f26c8d7> in <module>
# ----> 1 for no, value in enumerate(listem,0):
#       2     print('N: {0} V: {1}'.format(no,value ))
#
# NameError: name 'listem' is not defined

# %%
sinif=[0,0]
def not_hesaplama(ad, puanlar):
    sinif[0]+= len(puanlar)
    sinif[1]+= sum(puanlar) 
    ortalama = 0
    for puan in puanlar:
        ortalama += puan
    ortalama /= len(puanlar)
    #ortalama = sum(puanlar) / len(puanlar)
    
    if ortalama > 90:
        harf = 'A'
    elif ortalama > 80:
        harf = 'B'
    elif ortalama > 60:
        harf = 'C'
    elif ortalama > 50:
        harf = 'D'
    else:
        harf = 'F'
    
    print(f'\nİsim: {ad}\nOrtalama: {ortalama:.2f}\nHarf notu: {harf}\n', end="-"*20)

not_hesaplama('Ahmet DENİZ', (60, 100, 75))
not_hesaplama('Aylin TÜRK', (20, 50, 65))
not_hesaplama('Murat YILMAZ', (100, 100, 85))
sinif_ort= sinif[1]//sinif[0]
print(f'\nSınıf ort: {sinif_ort}\n', end="-"*20)
# Out:
# İsim: Ahmet DENİZ
# Ortalama: 78.33
# Harf notu: C
# --------------------
# İsim: Aylin TÜRK
# Ortalama: 45.00
# Harf notu: F
# --------------------
# İsim: Murat YILMAZ
# Ortalama: 95.00
# Harf notu: A
# --------------------
# Sınıf ort: 72
# --------------------

# %%
a=8
sonuc=1
def factorial(a):
    global sonuc
    if(a==1):       
        return 1
    sonuc=factorial(a-1)*a
    return sonuc
print(f"{factorial(a)} {sonuc} {a}")
# Out:
# 40320 40320 8

# %%
# house list of lists
import numpy as np
house = [["hallway", 11.25], 
         ["kitchen", 18.0], 
         ["living room", 20.0], 
         ["bedroom", 10.75], 
         ["bathroom", 9.50]]
         
# Build a for loop from scratch
for room in house :
    print('the '+room[0]+' is '+str(room[1]) +' sqm')

for room, m2 in np.array(house) :
    print('np - the '+room+' is '+str(m2) +' sqm')
# Out:
# the hallway is 11.25 sqm
# the kitchen is 18.0 sqm
# the living room is 20.0 sqm
# the bedroom is 10.75 sqm
# the bathroom is 9.5 sqm
# np - the hallway is 11.25 sqm
# np - the kitchen is 18.0 sqm
# np - the living room is 20.0 sqm
# np - the bedroom is 10.75 sqm
# np - the bathroom is 9.5 sqm

# %%
import pandas as pd
cars=    {'index':['US','AUS','JPN','IN','RU','MOR','EG'],
    'cars_per_cap':{809,731,588,18,200,70,45},
         'country':{'United States','Australia','Japan','India','Russia','Morocca','Egypt'},
    'drives_right':{True,False,False,False,True,True,True}
cars2= [['US',809,'United States',True ],
    ['AUS',           731  ,    'Australia',         False],
['JPN',           588   ,       'Japan',         False],
['IN',             18  ,        'India',         False],
['RU',            200  ,       'Russia',          True],
['MOR',            70  ,      'Morocco',          True],
['EG',             45  ,        'Egypt',          True]]
cars2.columns=['index','cars_per_cap',        'country'  ,'drives_right']
#cars = pd.read_csv('cars.csv', index_col = 0)

cars2["country"].apply(str.upper)
# Use .apply(str.upper)
#for lab, row in cars.iterrows() :
#    cars.loc[lab, "COUNTRY"] = row["country"].upper()
print(cars)
# Out:
#   File "<ipython-input-36-26f37fd10fa6>", line 6
#     cars2= [['US',809,'United States',True ],
#     ^
# SyntaxError: invalid syntax

# %%
import numpy as np
np.random.seed(123)
tries=[]
tails=[0]
for x in range(10):
    try_=np.random.randint(0,2)
    if(try_==1): 
        tries.append("head")
    else  :
        tries.append("tail")
    tails.append(tails[x]+try_)
print(tries)
print(tails)
# Out:
# ['tail', 'head', 'tail', 'tail', 'tail', 'tail', 'tail', 'head', 'head', 'tail']
# [0, 0, 1, 1, 1, 1, 1, 1, 2, 3, 3]

# %%
import matplotlib.pyplot as plt
plt.hist(tails,10)
plt.show()

# %%
# numpy and matplotlib imported, seed set.

# initialize and populate all_walks
all_walks = []
for i in range(10) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        random_walk.append(step)
    all_walks.append(random_walk)

# Convert all_walks to Numpy array: np_aw
np_aw=np.array(all_walks)

# Plot np_aw and show
plt.plot(np_aw)
plt.show()
# Clear the figure
plt.clf()

# Transpose np_aw: np_aw_t
np_aw_t=np_aw.transpose()

# Plot np_aw_t and show
plt.plot(np_aw_t)
plt.show()

# %%
# numpy and matplotlib imported, seed set

# Simulate random walk 250 times
all_walks = []
for i in range(250) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)

        # Implement clumsiness
        if np.random.rand()<=0.001:
            step = 0

        random_walk.append(step)
    all_walks.append(random_walk)

# Create and plot np_aw_t
np_aw_t = np.transpose(np.array(all_walks))
plt.plot(np_aw_t)
plt.show()

# %%
# numpy and matplotlib imported, seed set

# Simulate random walk 500 times
all_walks = []
for i in range(500) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        if np.random.rand() <= 0.001 :
            step = 0
        random_walk.append(step)
    all_walks.append(random_walk)

# Create and plot np_aw_t
np_aw_t = np.transpose(np.array(all_walks))

# Select last row from np_aw_t: ends
ends = np_aw_t[-1]

# Plot histogram of ends, display plot
plt.hist(ends*2, 500)

plt.show()

# %%
  print(np.count_nonzero(ends>=60)/ends.size)
# Out:
# 0.746

# %%
n = int(input("Küme sayısını girin: "))
ar = input("Listeyi girin: ")
ar= ar.split()
print(n, ar)
# Out:
# 10 ['10', '20', '10', '10', '10', '20', '30', '40', '50', '80']

# %%
my_dict={}
for s in ar:
    if s in my_dict:
        my_dict[s]=my_dict[s]+1
    else:
        my_dict[s]=1
total=0
for v in my_dict.values():
    total = total+int(v/2)
    
print(total)
# Out:
# 3
